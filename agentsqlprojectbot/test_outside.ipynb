# %%
import os
val = os.environ.get("MASTER_PASSWORD_HASH")
print(repr(val))  # سيظهر None إذا لم يُحمّل
# Out:
# 'd7de38d2b6d5162eb62a5770adadaa7d$060aed066c2485bf07bd4212e703d8f4a71e12277d7affdbc1201314aa043a6b'
